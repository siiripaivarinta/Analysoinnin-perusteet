# %%
import pandas as pd

# %%
# 4. Declare a string typed variable. Name it creator. Assign your name as the value of the creator variable.
creator = "Siiri Päivärinta"
# 6. Declare two numeric variables (for example integers). Name them as number1 and number2.
number1 = 16
number2 = 32

# 2. Print “Printer App”.
print ("Printer App")
# 3. Print “This app is made by:”.
print ("This app is made by: ")
# 5. Print the value of the creator. Try to get it on a same line as “This app is made by:”. 
print ("This app is made by: " + creator)

# 7. First, try to print the value of number1. When done, comment the line. 
# print(number1)
# 8. Print “The value of number1 is 5”.
print (f"The value of number1 is: {number1}")
# 9. Print “The value of number2 is 3”.
print (f"The value of number2 is: {number2}")

# 10. Declare integer typed variable called multiplication.
# 11. Multiply number1 and number2 and assign the result to the multiplication variable. 
multiplication = number1 * number2 
# 12. Print “5 * 2 = 10”
print (f"{number1} * {number2} = {multiplication}")

# 13. Repeat 10-12 for addition, division and substraction. 
addition = number1 + number2
print (f"{number1} + {number2} = {addition}")

division = number2 / number1
print (f"{number2} / {number1} = {division}")

subtraction = number2 - number1
print (f"{number2} - {number1} = {subtraction}")
# Out:
# Printer App
# This app is made by:
# This app is made by: Siiri Päivärinta
# The value of number1 is: 16
# The value of number2 is: 32
# 16 * 32 = 512
# 16 + 32 = 48
# 32 / 16 = 2.0
# 32 - 16 = 16
